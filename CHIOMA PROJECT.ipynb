# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

print('ready')
# Out:
# ready

# %%
df = pd.read_csv("./datasets/africa_food_prices.csv")

# %%
df
# Out:
#         Unnamed: 0  country_id   country  state_id     state  market_id  \
# 0            15427         4.0   Algeria       344     Alger       1794
# 1            15428         4.0   Algeria       344     Alger       1794
# 2            15429         4.0   Algeria       344     Alger       1794
# 3            15430         4.0   Algeria       344     Alger       1794
# 4            15431         4.0   Algeria       344     Alger       1794
# ...            ...         ...       ...       ...       ...        ...
# 956774     2050633       271.0  Zimbabwe      3444  Midlands       5594
# 956775     2050634       271.0  Zimbabwe      3444  Midlands       5594
# 956776     2050635       271.0  Zimbabwe      3444  Midlands       5594
# 956777     2050636       271.0  Zimbabwe      3444  Midlands       5594
# 956778     2050637       271.0  Zimbabwe      3444  Midlands       5594
#
#             market  produce_id                  produce  currency_id currency  \
# ...

# %%
#basic information 
df.info()

#describe the data
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956779 entries, 0 to 956778
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          956779 non-null  int64
#  1   country_id          956779 non-null  float64
#  2   country             956779 non-null  object
#  3   state_id            956779 non-null  int64
#  4   state               830101 non-null  object
#  5   market_id           956779 non-null  int64
#  6   market              956779 non-null  object
#  7   produce_id          956779 non-null  int64
#  8   produce             956779 non-null  object
#  9   currency_id         956779 non-null  float64
#  10  currency            956779 non-null  object
#  11  pt_id               956779 non-null  int64
#  12  market_type         956779 non-null  object
#  13  um_unit_id          956779 non-null  int64
#  14  quantity            956779 non-null  object
# ...

# %%
df.shape
# Out:
# (956779, 19)

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 956774    False
# 956775    False
# 956776    False
# 956777    False
# 956778    False
# Length: 956779, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# dropping the Unnamed columns
col_to_drop = ['Unnamed: 0']
df = df.drop(columns=col_to_drop, axis=0)

# %%
# dropping mp_commoditysource column because of the null values 
col_to_drop = ['mp_commoditysource']
df = df.drop(columns=col_to_drop, axis=-1)

# %%
df.shape

# %%
#to find the null values

df.isnull().sum()

# %%
# drop rows null values in state
df = df.dropna(subset=['state'])

# %%
df.isnull().sum()

# %%
#datatype

df.dtypes

# %%
# columns

df.columns
# Out:
# Index(['country_id', 'country', 'state_id', 'state', 'market_id', 'market',
#        'produce_id', 'produce', 'currency_id', 'currency', 'pt_id',
#        'market_type', 'um_unit_id', 'quantity', 'month', 'year', 'price'],
#       dtype='object')

# %%
cols_to_drop = ['country_id', 'state_id','market_id','produce_id','currency_id','pt_id','um_unit_id']

df = df.drop(columns=cols_to_drop, axis=1)

# %%
df
# Out:
#          country     state      market                  produce currency  \
# 0        Algeria     Alger     Algiers            Rice - Retail      DZD
# 1        Algeria     Alger     Algiers            Rice - Retail      DZD
# 2        Algeria     Alger     Algiers            Rice - Retail      DZD
# 3        Algeria     Alger     Algiers            Rice - Retail      DZD
# 4        Algeria     Alger     Algiers            Rice - Retail      DZD
# ...          ...       ...         ...                      ...      ...
# 956774  Zimbabwe  Midlands  Mbilashaba   Beans (sugar) - Retail      ZWL
# 956775  Zimbabwe  Midlands  Mbilashaba      Toothpaste - Retail      ZWL
# 956776  Zimbabwe  Midlands  Mbilashaba    Laundry soap - Retail      ZWL
# 956777  Zimbabwe  Midlands  Mbilashaba   Handwash soap - Retail      ZWL
# 956778  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta) - Retail      ZWL
#
#        market_type quantity  month  year      price
# ...

# %%
df.shape
# Out:
# (830101, 10)

# %%
print(df['produce'][0])
# Out:
# Rice - Retail

# %%
#split on the left most parenthesis as the delimeter


temp = df['produce'].str.split("-", n=1, expand =True)

# %%
temp
# Out:
#                       0        1
# 0                 Rice    Retail
# 1                 Rice    Retail
# 2                 Rice    Retail
# 3                 Rice    Retail
# 4                 Rice    Retail
# ...                 ...      ...
# 956774   Beans (sugar)    Retail
# 956775      Toothpaste    Retail
# 956776    Laundry soap    Retail
# 956777   Handwash soap    Retail
# 956778  Fish (kapenta)    Retail
#
# [830101 rows x 2 columns]

# %%
#replace the produce column in df with the temp[0]


df['produce']= temp[0]

# %%
df.head()
# Out:
#    country  state   market produce currency market_type quantity  month  year  \
# 0  Algeria  Alger  Algiers   Rice       DZD      Retail       KG      4  2015
# 1  Algeria  Alger  Algiers   Rice       DZD      Retail       KG      5  2015
# 2  Algeria  Alger  Algiers   Rice       DZD      Retail       KG      6  2015
# 3  Algeria  Alger  Algiers   Rice       DZD      Retail       KG      7  2015
# 4  Algeria  Alger  Algiers   Rice       DZD      Retail       KG      8  2015
#
#    price
# 0   90.0
# 1   96.0
# 2   96.0
# 3   83.0
# 4   80.0

# %%
df.tail()
# Out:
#          country     state      market          produce currency market_type  \
# 956774  Zimbabwe  Midlands  Mbilashaba   Beans (sugar)       ZWL      Retail
# 956775  Zimbabwe  Midlands  Mbilashaba      Toothpaste       ZWL      Retail
# 956776  Zimbabwe  Midlands  Mbilashaba    Laundry soap       ZWL      Retail
# 956777  Zimbabwe  Midlands  Mbilashaba   Handwash soap       ZWL      Retail
# 956778  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta)       ZWL      Retail
#
#        quantity  month  year      price
# 956774       KG      6  2021   233.3333
# 956775   100 ML      6  2021   112.5000
# 956776       KG      6  2021   114.0000
# 956777    250 G      6  2021    59.5000
# 956778       KG      6  2021  1200.0000

# %%
df['quantity'] = df['quantity'].replace(['250 G', 'G', '100 ML', 'ML'])

print(df)
# Out:
#          country     state      market          produce currency market_type  \
# 0        Algeria     Alger     Algiers            Rice       DZD      Retail
# 1        Algeria     Alger     Algiers            Rice       DZD      Retail
# 2        Algeria     Alger     Algiers            Rice       DZD      Retail
# 3        Algeria     Alger     Algiers            Rice       DZD      Retail
# 4        Algeria     Alger     Algiers            Rice       DZD      Retail
# ...          ...       ...         ...              ...      ...         ...
# 956774  Zimbabwe  Midlands  Mbilashaba   Beans (sugar)       ZWL      Retail
# 956775  Zimbabwe  Midlands  Mbilashaba      Toothpaste       ZWL      Retail
# 956776  Zimbabwe  Midlands  Mbilashaba    Laundry soap       ZWL      Retail
# 956777  Zimbabwe  Midlands  Mbilashaba   Handwash soap       ZWL      Retail
# 956778  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta)       ZWL      Retail
#
#        quantity  month  year      price
# ...

# %%
df.dtypes
# Out:
# country         object
# state           object
# market          object
# produce         object
# currency        object
# market_type     object
# quantity        object
# month            int64
# year             int64
# price          float64
# dtype: object

# %%
#Reenaming the Columns
df = df.rename(columns= { 'country' : 'Country' , 'state': 'State', 'market' : 'Market', 
                         'produce': 'Produce', 'currency': 'Currency',
                         'market_type':'Market_Type',
                         'quantity':'Quantity', 'month':'Month', 
                         'year':'Year', 'price':'Price'})

# %%
df
# Out:
#          Country     State      Market          Produce Currency Market_Type  \
# 0        Algeria     Alger     Algiers            Rice       DZD      Retail
# 1        Algeria     Alger     Algiers            Rice       DZD      Retail
# 2        Algeria     Alger     Algiers            Rice       DZD      Retail
# 3        Algeria     Alger     Algiers            Rice       DZD      Retail
# 4        Algeria     Alger     Algiers            Rice       DZD      Retail
# ...          ...       ...         ...              ...      ...         ...
# 956774  Zimbabwe  Midlands  Mbilashaba   Beans (sugar)       ZWL      Retail
# 956775  Zimbabwe  Midlands  Mbilashaba      Toothpaste       ZWL      Retail
# 956776  Zimbabwe  Midlands  Mbilashaba    Laundry soap       ZWL      Retail
# 956777  Zimbabwe  Midlands  Mbilashaba   Handwash soap       ZWL      Retail
# 956778  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta)       ZWL      Retail
#
#        Quantity  Month  Year      Price
# ...

# %%
df.Produce
# Out:
# 0                   Rice
# 1                   Rice
# 2                   Rice
# 3                   Rice
# 4                   Rice
#                ...
# 956774     Beans (sugar)
# 956775        Toothpaste
# 956776      Laundry soap
# 956777     Handwash soap
# 956778    Fish (kapenta)
# Name: Produce, Length: 830101, dtype: object

# %%
#To display the maximum produce 

df['Produce'].max()
# Out:
# 'Zucchini '

# %%
#To display all the maximum produce 

df[df.Produce ==df['Produce'].max()]
# Out:
#        Country                         State            Market    Produce  \
# 656634  Rwanda  Kigali City/Umujyi wa Kigali           Gahanga  Zucchini
# 656635  Rwanda  Kigali City/Umujyi wa Kigali           Gahanga  Zucchini
# 656636  Rwanda  Kigali City/Umujyi wa Kigali           Gahanga  Zucchini
# 656637  Rwanda  Kigali City/Umujyi wa Kigali           Gahanga  Zucchini
# 656638  Rwanda  Kigali City/Umujyi wa Kigali           Gahanga  Zucchini
# ...        ...                           ...               ...        ...
# 788488  Rwanda           West/Iburengerazuba  Kibuye (Karongi)  Zucchini
# 788489  Rwanda           West/Iburengerazuba  Kibuye (Karongi)  Zucchini
# 788490  Rwanda           West/Iburengerazuba  Kibuye (Karongi)  Zucchini
# 788491  Rwanda           West/Iburengerazuba  Kibuye (Karongi)  Zucchini
# 789697  Rwanda           West/Iburengerazuba            Bumazi  Zucchini
#
#        Currency Market_Type Quantity  Month  Year     Price
# ...

# %%
df.to_csv("./africa_food_prices_cleaned.csv",index= False)

# %%
africa_food = pd.read_csv('./africa_food_prices_cleaned.csv')

# %%
africa_food
# Out:
#          Country     State      Market          Produce Currency Market_Type  \
# 0        Algeria     Alger     Algiers            Rice       DZD      Retail
# 1        Algeria     Alger     Algiers            Rice       DZD      Retail
# 2        Algeria     Alger     Algiers            Rice       DZD      Retail
# 3        Algeria     Alger     Algiers            Rice       DZD      Retail
# 4        Algeria     Alger     Algiers            Rice       DZD      Retail
# ...          ...       ...         ...              ...      ...         ...
# 830096  Zimbabwe  Midlands  Mbilashaba   Beans (sugar)       ZWL      Retail
# 830097  Zimbabwe  Midlands  Mbilashaba      Toothpaste       ZWL      Retail
# 830098  Zimbabwe  Midlands  Mbilashaba    Laundry soap       ZWL      Retail
# 830099  Zimbabwe  Midlands  Mbilashaba   Handwash soap       ZWL      Retail
# 830100  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta)       ZWL      Retail
#
#        Quantity  Month  Year      Price
# ...

# %%
# To group by year 
df.groupby('Year').Produce.describe()
# Out:
#        count unique               top  freq
# Year
# 1990     140      3           Millet     58
# 1991     134      3           Millet     56
# 1992     144      3           Millet     60
# 1993     138      3           Millet     60
# 1994     813      5           Millet    334
# 1995     860      7           Millet    342
# 1996     970      7           Millet    344
# 1997     992     10           Millet    348
# 1998    1129     10           Millet    356
# 1999    1067     10           Millet    339
# 2000    1137     15           Millet    367
# 2001    1565     17           Millet    378
# 2002    1964     18           Millet    429
# 2003    3603     22    Maize (white)    680
# 2004    3804     25    Maize (white)    702
# 2005    4780     32            Maize    961
# 2006    8240     51            Maize   1217
# 2007   14016     59           Millet   2192
# 2008   19618     80          Sorghum   2331
# 2009   22752     78          Sorghum   2864
# ...

# %%
df['Year'].value_counts()
# Out:
# 2020    129745
# 2021     79145
# 2019     76602
# 2015     66779
# 2018     65169
# 2014     60673
# 2017     58949
# 2013     55980
# 2016     46628
# 2012     44642
# 2011     32461
# 2010     25462
# 2009     22752
# 2008     19618
# 2007     14016
# 2006      8240
# 2005      4780
# 2004      3804
# 2003      3603
# 2002      1964
# 2001      1565
# 2000      1137
# 1998      1129
# 1999      1067
# 1997       992
# 1996       970
# 1995       860
# 1994       813
# 1992       144
# 1990       140
# 1993       138
# 1991       134
# Name: Year, dtype: int64

# %%
# To group by year 
df.groupby('Year').Price.describe()
# Out:
#          count          mean            std      min         25%       50%  \
# Year
# 1990     140.0     98.357143      62.153103  41.0000   53.750000   69.5000
# 1991     134.0    101.854478      53.885175  34.0000   61.250000   80.5000
# 1992     144.0     97.531250      58.906178  37.0000   57.000000   69.0000
# 1993     138.0     96.474638      61.591257  32.0000   55.000000   67.0000
# 1994     813.0    116.973555      69.368347  32.0000   66.000000   88.0000
# 1995     860.0    144.623256     321.126372  41.0000   73.000000   91.0000
# 1996     970.0    463.944330    1665.649507  55.0000  107.000000  146.0000
# 1997     992.0   2110.807460   27602.423894  77.0000  142.750000  179.0000
# 1998    1129.0   6019.996457   51629.054868  58.0000  158.000000  218.0000
# 1999    1067.0   2978.741331   32388.104561  54.0000  106.000000  153.0000
# 2000    1137.0   7464.522280   72221.455359   0.5023  117.000000  139.4290
# ...

# %% [markdown]
# # BAR CHARTPLOT

# %%
df['Year'].value_counts() \
    .head(20)\
    .plot(kind='bar', title='Top Years Africa Food Price')
# Out:
# <AxesSubplot:title={'center':'Top Years Africa Food Price'}>

# %%
africafoodprice=df['Year'].value_counts() \
    .head(20)\
    .plot(kind='bar', title='Top Years Africa Food Price')
africafoodprice.set_xlabel('Top Year')
africafoodprice.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['Price'].value_counts()
# Out:
# 200.0000     16501
# 500.0000     15010
# 300.0000     13618
# 400.0000     13141
# 250.0000     12504
#              ...
# 14.3850          1
# 33.9200          1
# 34.3233          1
# 40.1633          1
# 1123.3333        1
# Name: Price, Length: 101609, dtype: int64

# %%
df['Price'].value_counts()\
    .head(20)\
    .plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# HISTOGRAPY CHART

df=df['Year'].plot(kind='hist')
df.set_xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
africa_food
# Out:
#          Country     State      Market          Produce Currency Market_Type  \
# 0        Algeria     Alger     Algiers            Rice       DZD      Retail
# 1        Algeria     Alger     Algiers            Rice       DZD      Retail
# 2        Algeria     Alger     Algiers            Rice       DZD      Retail
# 3        Algeria     Alger     Algiers            Rice       DZD      Retail
# 4        Algeria     Alger     Algiers            Rice       DZD      Retail
# ...          ...       ...         ...              ...      ...         ...
# 830096  Zimbabwe  Midlands  Mbilashaba   Beans (sugar)       ZWL      Retail
# 830097  Zimbabwe  Midlands  Mbilashaba      Toothpaste       ZWL      Retail
# 830098  Zimbabwe  Midlands  Mbilashaba    Laundry soap       ZWL      Retail
# 830099  Zimbabwe  Midlands  Mbilashaba   Handwash soap       ZWL      Retail
# 830100  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta)       ZWL      Retail
#
#        Quantity  Month  Year      Price
# ...

# %%
africa_food.Country.unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Burundi', 'Cameroon', 'Cape Verde',
#        'Central African Republic', 'Congo', 'Djibouti', 'Eritrea',
#        'Ethiopia', 'Gabon', 'Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau',
#        'Kenya', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Mali',
#        'Mauritania', 'Namibia', 'Niger', 'Nigeria', 'Rwanda', 'Senegal',
#        'Sierra Leone', 'Somalia', 'South Africa', 'Sudan', 'Togo',
#        'Uganda', 'Zambia', 'Zimbabwe'], dtype=object)

# %% [markdown]
# # Filtering By country Algeria

# %%
africa_food.Country= africa_food.Country.str.strip()

# %%
Country_list = ['Algeria']
africa_food[africa_food.Country.isin(Country_list)]
# Out:
#       Country    State   Market      Produce Currency Market_Type Quantity  \
# 0     Algeria    Alger  Algiers        Rice       DZD      Retail       KG
# 1     Algeria    Alger  Algiers        Rice       DZD      Retail       KG
# 2     Algeria    Alger  Algiers        Rice       DZD      Retail       KG
# 3     Algeria    Alger  Algiers        Rice       DZD      Retail       KG
# 4     Algeria    Alger  Algiers        Rice       DZD      Retail       KG
# ...       ...      ...      ...          ...      ...         ...      ...
# 1788  Algeria  Tindouf   Layoun  Tea (sahm)       DZD      Retail   Packet
# 1789  Algeria  Tindouf   Layoun  Tea (sahm)       DZD      Retail   Packet
# 1790  Algeria  Tindouf   Layoun  Tea (sahm)       DZD      Retail   Packet
# 1791  Algeria  Tindouf   Layoun  Tea (sahm)       DZD      Retail   Packet
# 1792  Algeria  Tindouf   Layoun  Tea (sahm)       DZD      Retail   Packet
#
#       Month  Year  Price
# 0         4  2015   90.0
# ...

# %%
africa_food.columns
# Out:
# Index(['Country', 'State', 'Market', 'Produce', 'Currency', 'Market_Type',
#        'Quantity', 'Month', 'Year', 'Price'],
#       dtype='object')

# %%
africa_food['Market_Type'].unique()
# Out:
# array(['Retail', 'Wholesale', 'Producer'], dtype=object)

# %%
africa_food.Market_Type.value_counts()
# Out:
# Retail       760921
# Wholesale     68932
# Producer        248
# Name: Market_Type, dtype: int64

# %% [markdown]
# # PIVOT TABLE

# %%
pd.pivot_table(africa_food, index = "Market_Type")
# Out:
#                 Month        Price         Year
# Market_Type
# Producer     6.459677   666.338710  2011.471774
# Retail       6.391084  4155.370462  2015.620712
# Wholesale    6.396782  8782.038273  2014.673504

# %%
pd.pivot_table(africa_food,index="Produce")
# Out:
#                         Month        Price         Year
# Produce
# Apples               7.000000   318.400000  2015.550000
# Apples (red)         6.489646  1190.806780  2016.548430
# Avocados             6.792958   260.170797  2014.647608
# Bananas              6.475452   386.272507  2016.333735
# Bananas (imported)   5.400000  1460.333333  2020.800000
# ...                       ...          ...          ...
# Yam (puna)           6.474729   227.662762  2020.043321
# Yam (white)          6.016497   358.252135  2019.986041
# Yam (yellow)         5.484375   362.535103  2020.484375
# Yogurt               6.200000    23.107637  2020.400000
# Zucchini             6.324360   274.504520  2013.068286
#
# [334 rows x 3 columns]

# %%
#Country_list = ['Algeria']
#africa_food[africa_food.Country.isin(Country_list)]

pd.pivot_table(africa_food, index= ["Country","Market_Type"], values = "Produce", aggfunc=["sum","count"])
# Out:
#                                                                                     sum  \
#                                                                                 Produce
# Country                  Market_Type
# Algeria                  Retail       Rice Rice Rice Rice Rice Rice Rice Rice Rice R...
# Angola                   Retail       Bread Bread Bread Bread Bread Bread Bread Brea...
# Benin                    Retail       Oil (palm) Oil (palm) Oil (palm) Oil (palm) Oi...
#                          Wholesale    Maize Maize Maize Maize Maize Maize Maize Maiz...
# Burundi                  Retail       Beans Beans Beans Beans Beans Beans Beans Bean...
#                          Wholesale    Maize Maize Maize Maize Maize Maize Maize Maiz...
# Cameroon                 Retail       Maize Maize Maize Maize Maize Oil (palm) Oil (...
#                          Wholesale    Maize Maize Maize Maize Maize Maize Maize Maiz...
# ...

# %%
pd.set_option("display.max_rows", 400)

# %%
africa_food
# Out:
#          Country     State      Market          Produce Currency Market_Type  \
# 0        Algeria     Alger     Algiers            Rice       DZD      Retail
# 1        Algeria     Alger     Algiers            Rice       DZD      Retail
# 2        Algeria     Alger     Algiers            Rice       DZD      Retail
# 3        Algeria     Alger     Algiers            Rice       DZD      Retail
# 4        Algeria     Alger     Algiers            Rice       DZD      Retail
# ...          ...       ...         ...              ...      ...         ...
# 830096  Zimbabwe  Midlands  Mbilashaba   Beans (sugar)       ZWL      Retail
# 830097  Zimbabwe  Midlands  Mbilashaba      Toothpaste       ZWL      Retail
# 830098  Zimbabwe  Midlands  Mbilashaba    Laundry soap       ZWL      Retail
# 830099  Zimbabwe  Midlands  Mbilashaba   Handwash soap       ZWL      Retail
# 830100  Zimbabwe  Midlands  Mbilashaba  Fish (kapenta)       ZWL      Retail
#
#        Quantity  Month  Year      Price
# ...

# %%
africa_food.columns
# Out:
# Index(['Country', 'State', 'Market', 'Produce', 'Currency', 'Market_Type',
#        'Quantity', 'Month', 'Year', 'Price'],
#       dtype='object')

# %%
print(africa_food.Country[0])
# Out:
# Algeria
